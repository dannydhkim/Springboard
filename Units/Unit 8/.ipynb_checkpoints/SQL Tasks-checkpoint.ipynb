# %%
import sqlite3
from sqlalchemy import create_engine
import pandas as pd

conn = sqlite3.connect('country_club.db')
c = conn.cursor()
print('Database created and connected')

bookings_df = pd.read_csv('Bookings.csv')
bookings_df.to_sql('Bookings', conn, if_exists='replace', index=False)
facilities_df = pd.read_csv('Facilities.csv')
facilities_df.to_sql('Facilities', conn, if_exists='replace', index=False)
members_df = pd.read_csv('Members.csv')
members_df.to_sql('Members', conn, if_exists='replace', index=False)
# Out:
# Database created and connected

# %%
c.execute('''
SELECT * 
FROM Members
''')

# %%
df = pd.DataFrame(c.fetchall())
df
# Out:
#      0                  1          2                                        3  \
# 0    1              Smith     Darren               8 Bloomsbury Close, Boston
# 1    2              Smith      Tracy             8 Bloomsbury Close, New York
# 2    3             Rownam        Tim                   23 Highway Way, Boston
# 3    4           Joplette     Janice               20 Crossing Road, New York
# 4    5            Butters     Gerald           1065 Huntingdon Avenue, Boston
# 5    6              Tracy     Burton                  3 Tunisia Drive, Boston
# 6    7               Dare      Nancy              6 Hunting Lodge Way, Boston
# 7    8             Boothe        Tim       3 Bloomsbury Close, Reading, 00234
# 8    9           Stibbons     Ponder                5 Dragons Way, Winchester
# 9   10               Owen    Charles     52 Cheshire Grove, Winchester, 28563
# 10  11              Jones      David                 976 Gnats Close, Reading
# 11  12              Baker       Anne                55 Powdery Street, Boston
# 12  13            Farrell     Jemima          103 Firth Avenue, North Reading
# 13  14              Smith       Jack               252 Binkington Way, Boston
# 14  15              Bader   Florence               264 Ursula Drive, Westford
# 15  16              Baker    Timothy                329 James Street, Reading
# 16  17             Pinker      David                   5 Impreza Road, Boston
# 17  20            Genting    Matthew    4 Nunnington Place, Wingfield, Boston
# 18  21          Mackenzie       Anna              64 Perkington Lane, Reading
# 19  22             Coplin       Joan      85 Bard Street, Bloomington, Boston
# 20  24             Sarwin  Ramnaresh               12 Bullington Lane, Boston
# 21  26              Jones    Douglas                 976 Gnats Close, Reading
# 22  27             Rumney  Henrietta               3 Burkington Plaza, Boston
# 23  28            Farrell      David          437 Granite Farm Road, Westford
# 24  29  Worthington-Smyth      Henry              55 Jagbi Way, North Reading
# 25  30            Purview  Millicent   641 Drudgery Close, Burnington, Boston
# 26  33         Tupperware   Hyacinth  33 Cheerful Plaza, Drake Road, Westford
# 27  35               Hunt       John                5 Bullington Lane, Boston
# 28  36            Crumpet      Erica              Crimson Road, North Reading
# 29  37              Smith     Darren           3 Funktown, Denzington, Boston
#
#         4               5     6                    7
# 0    4321    555-555-5555   NaN  2012-07-02 12:02:05
# 1    4321    555-555-5555   NaN  2012-07-02 12:08:23
# 2   23423  (844) 693-0723   NaN  2012-07-03 09:32:15
# 3     234  (833) 942-4710   1.0  2012-07-03 10:25:05
# 4   56754  (844) 078-4130   1.0  2012-07-09 10:44:09
# 5   45678  (822) 354-9973   NaN  2012-07-15 08:52:55
# 6   10383  (833) 776-4001   4.0  2012-07-25 08:59:12
# 7     234  (811) 433-2547   3.0  2012-07-25 16:02:35
# 8   87630  (833) 160-3900   6.0  2012-07-25 17:09:05
# 9   28563  (855) 542-5251   1.0  2012-08-03 19:42:37
# 10  33862  (844) 536-8036   4.0  2012-08-06 16:32:55
# 11  80743    844-076-5141   9.0  2012-08-10 14:23:22
# 12  57392  (855) 016-0163   NaN  2012-08-10 14:28:01
# 13  69302  (822) 163-3254   1.0  2012-08-10 16:22:05
# 14  84923  (833) 499-3527   9.0  2012-08-10 17:52:03
# 15  58393    833-941-0824  13.0  2012-08-15 10:34:25
# 16  65332    811 409-6734  13.0  2012-08-16 11:32:47
# 17  52365  (811) 972-1377   5.0  2012-08-19 14:55:55
# 18  64577  (822) 661-2898   1.0  2012-08-26 09:32:05
# 19  43533  (822) 499-2232  16.0  2012-08-29 08:32:41
# 20  65464  (822) 413-1470  15.0  2012-09-01 08:44:42
# 21  11986    844 536-8036  11.0  2012-09-02 18:43:05
# 22  78533  (822) 989-8876  20.0  2012-09-05 08:42:35
# 23  43532  (855) 755-9876   NaN  2012-09-15 08:22:05
# 24  97676  (855) 894-3758   2.0  2012-09-17 12:27:15
# 25  34232  (855) 941-9786   2.0  2012-09-18 19:04:01
# 26  68666  (822) 665-5327   NaN  2012-09-18 19:32:05
# 27  54333  (899) 720-6978  30.0  2012-09-19 11:32:45
# 28  75655  (811) 732-4816   2.0  2012-09-22 08:36:38
# 29  66796  (822) 577-3541   NaN  2012-09-26 18:08:45
